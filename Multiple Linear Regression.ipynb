# %%
from IPython.display import Image
Image("/Users/priyashaprasad/Desktop/Screenshot 2020-06-23 at 2.22.34 PM.png")

# %% [markdown]
# StreetEasy is New York City’s leading real estate marketplace — from studios to high-rises, Brooklyn Heights to Harlem.

# %%
Image("/Users/priyashaprasad/Desktop/Screenshot 2020-06-23 at 2.29.21 PM.png")

# %%
Image("/Users/priyashaprasad/Desktop/Screenshot 2020-06-23 at 2.29.35 PM.png")

# %%
Image("/Users/priyashaprasad/Desktop/Screenshot 2020-06-23 at 2.29.45 PM.png")

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/priyashaprasad/Documents/Codecademy - ML/manhattan.csv")

# %%
df.head()
# Out:
#    rental_id   rent  bedrooms  bathrooms  size_sqft  min_to_subway  floor  \
# 0       1545   2550       0.0          1        480              9    2.0
# 1       2472  11500       2.0          2       2000              4    1.0
# 2       2919   4500       1.0          1        916              2   51.0
# 3       2790   4795       1.0          1        975              3    8.0
# 4       3946  17500       2.0          2       4800              3    4.0
#
#    building_age_yrs  no_fee  has_roofdeck  has_washer_dryer  has_doorman  \
# 0                17       1             1                 0            0
# 1                96       0             0                 0            0
# 2                29       0             1                 0            1
# 3                31       0             0                 0            1
# 4               136       0             0                 0            1
#
#    has_elevator  has_dishwasher  has_patio  has_gym       neighborhood  \
# ...

# %%
df.shape
# Out:
# (3539, 18)

# %%
x = df[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym']]

# %%
y = df[['rent']]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2,random_state=6)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2831, 14)
# (708, 14)
# (2831, 1)
# (708, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
mlr.fit(x_train, y_train)
y_predict = mlr.predict(x_test)

# %%
y_predict
# Out:
# array([[ 3206.74211706],
#        [ 3847.14817924],
#        [ 4425.78377303],
#        [ 2825.53009497],
#        [ 5841.3080071 ],
#        [ 2621.98757614],
#        [ 3892.22170587],
#        [ 3625.85842968],
#        [ 5926.86373978],
#        [ 7615.48640874],
#        [ 9677.61737054],
#        [ 6950.18653716],
#        [ 3561.76885285],
#        [11635.75018584],
#        [ 4689.68372648],
#        [ 2869.91499472],
#        [ 8102.36092105],
#        [ 3267.4344105 ],
#        [ 2876.71427783],
#        [ 8338.74246474],
#        [ 7730.9863434 ],
#        [ 3722.39369082],
#        [ 1935.6987123 ],
#        [ 4940.41662206],
#        [11565.3210794 ],
#        [ 6222.70579085],
#        [ 4502.49541311],
#        [ 2276.38493743],
#        [ 2451.52625891],
#        [ 5517.67306166],
#        [ 2288.09313982],
#        [ 2759.33450117],
#        [ 2490.67950573],
#        [ 2171.53901411],
#        [ 3123.51788326],
#        [ 4867.17476808],
#        [ 4176.58123485],
# ...

# %%
sonny_apartment = [[1, 1, 620, 16, 1, 98, 1, 0, 1, 0, 0, 1, 1, 0]]

# %%
predict = mlr.predict(sonny_apartment)

# %%
print("Predicted rent: $%.2f" % predict)
# Out:
# Predicted rent: $2393.58

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_predict, alpha=0.4)

plt.xlabel("Prices: $Y_i$")
plt.ylabel("Predicted prices: $\hat{Y}_i$")
plt.title("Actual Rent vs Predicted Rent")
# Out:
# Text(0.5,1,'Actual Rent vs Predicted Rent')

# %%
print(mlr.coef_)
# Out:
# [[-302.73009383 1199.3859951     4.79976742  -24.28993151   24.19824177
#     -7.58272473 -140.90664773   48.85017415  191.4257324  -151.11453388
#     89.408889    -57.89714551  -19.31948556  -38.92369828]]

# %%
print(mlr.intercept_)
# Out:
# [-344.68587986]

# %%
plt.scatter(df[['size_sqft']], df[['rent']], alpha=0.4)

# %%
plt.scatter(df[['min_to_subway']], df[['rent']], alpha=0.4)

# %%
plt.scatter(df[['no_fee']], df[['rent']], alpha=0.4)

# %%
plt.scatter(df[['building_age_yrs']], df[['rent']], alpha=0.4)

# %%
print("Train score:")
print(mlr.score(x_train, y_train))

print("Test score:")
print(mlr.score(x_test, y_test))
# Out:
# Train score:
# 0.7725460559817883
# Test score:
# 0.805037197535764
